# %% [markdown]
# # Ejercicio: Data input, output e iteración
#
# En esta primera parte, aprenderemos a:
#
# * Descargar ficheros y renombrarlos por comandos de Linux (mucho más eficiente que recurrir a librerías de Python). Esta será una práctica a la que nos iremos habituando a lo largo del curso.
# * Leer y escribir ficheros en formato `csv` con la librería `pandas`.
# * Iterar sobre las filas de un objeto `pd.DataFrame`.
#
# En lo relativo a la primera parte, para la descarga emplearemos el comando `wget` seguido de la URL en cuestión. Para la segunda parte, usaremos la estructura `mv <source>  <destination>`:
#
# ```bash
# # Descargamos un fichero csv
# !wget https://www.stats.govt.nz/assets/Uploads/Gross-domestic-product/Gross-domestic-product-December-2021-quarter/Download-data/gross-domestic-product-December-2021-quarter-csv.csv
# # Lo renombramos para que sea más sencillo acceder a él
# !mv /content/gross-domestic-product-December-2021-quarter-csv.csv /content/dataset.csv
# ```
#
# Cuando trabajamos en notebooks, es más cómodo guardar la URL como un enlace, y posteriormente la librería `pandas` se encarga por nosotros de importarlo:

# %%
# Descargamos un fichero csv
URL_data='https://www.stats.govt.nz/assets/Uploads/Gross-domestic-product/Gross-domestic-product-December-2021-quarter/Download-data/gross-domestic-product-December-2021-quarter-csv.csv'

# %% [markdown]
# Seguidamente, procedemos a leerlo:

# %%
# Librerías
import os
import pandas as pd
# Leemos archivo
df = pd.read_csv(URL_data)

# %%
import seaborn as sns
sns.heatmap(df.isnull(),cbar=False)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'STATUS', 'UNITS',
#        'MAGNTUDE', 'Subject', 'Group', 'Series_title_1', 'Series_title_2',
#        'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %% [markdown]
# Es conveniente hacer uso de la librería `os`, ya que a bajo nivel nos gestiona cuál es nuestro directorio activo actual (`os.getcwd()`) y nos permite fácilmente concatenar rutas para encontrar archivos (`os.path.join()`).
#
# Veamos ahora cómo realizar iteraciones. En `pandas` existen esencialmente dos métodos para ello:
#
# * `iterrows`: Enlace a [documentación](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iterrows.html).
# * `itertuples`: Enlace a [documentación](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.itertuples.html).
#
# Tu objetivo será analizar la documentación e implementar un bucle donde se itere sobre las filas del `DataFrame` dejando un sencillo `pass` dentro del bucle, con el decorador `%%timeit` para evaluar qué método es más rápido. A continuación se muestra un ejemplo:
#
# ```python
# %%timeit
# for elem in [1,2,3,4,5]:
#     pass
# ```
#
# * Método iterrows:

# %%
# %%timeit
# Out:
# UsageError: %%timeit is a cell magic, but the cell body is empty. Did you mean the line magic %timeit (single %)?

# %% [markdown]
# *Tipo de respuesta esperada:*
#
# ```python
# 1 loop, best of 5: 3.28 s per loop
# ```
#
# * Método `itertuples` por defecto:

# %%
# %%timeit
# Out:
# 1 loop, best of 5: 117 ms per loop

# %% [markdown]
# *Tipo de respuesta esperada:*
#
# ```python
# 1 loop, best of 5: 117 ms per loop
# ```
#
# * Método `itertuples` sin contener los índices:

# %%
# %%timeit

# %% [markdown]
# *Tipo de respuesta esperada:*
#
# ```python
# 10 loops, best of 5: 118 ms per loop
# ```

# %% [markdown]
# # Ejercicio Ecommerce
#
# En este ejercicio, se proporcionan datos ficticios sobre compras realizadas por Amazon, por lo que es posible que exista alguna incoherencia en los datos. Se trata de ir realizando cada uno de los ejercicios propuestos progresivamente. Hay más de una forma de hacerlos, y todos se pueden responder con una línea.
#
# El enlace es:
#
# ```python
# URL_data = 'https://raw.githubusercontent.com/MatinMasimli/DataScience_ML_Udemy_Exercises/master/Ecommerce_purchases/Ecommerce%20Purchases.csv'
# ```

# %% [markdown]
# Cargamos la librería pandas como 'pd' y numpy como 'np':

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Ahora, leemos el DataFrame y mostramos sus cinco primeras filas:

# %%
df.head()             #por defecto, muestra 5, pero también se podría ecribir dentro
# Out:
#     Series_reference   Period  Data_value STATUS    UNITS  MAGNTUDE  \
# 0  SNEA.SG00NAC00B15  1972.03      6990.0  FINAL  Dollars         6
# 1  SNEA.SG00NAC00B15  1973.03      8080.0  FINAL  Dollars         6
# 2  SNEA.SG00NAC00B15  1974.03      9361.0  FINAL  Dollars         6
# 3  SNEA.SG00NAC00B15  1975.03     10203.0  FINAL  Dollars         6
# 4  SNEA.SG00NAC00B15  1976.03     11506.0  FINAL  Dollars         6
#
#                               Subject  \
# 0  National Accounts - SNA 2008 - SNE
# 1  National Accounts - SNA 2008 - SNE
# 2  National Accounts - SNA 2008 - SNE
# 3  National Accounts - SNA 2008 - SNE
# 4  National Accounts - SNA 2008 - SNE
#
#                                             Group  \
# 0  Series, Key aggregates, Nominal, Actual, Total
# 1  Series, Key aggregates, Nominal, Actual, Total
# 2  Series, Key aggregates, Nominal, Actual, Total
# 3  Series, Key aggregates, Nominal, Actual, Total
# 4  Series, Key aggregates, Nominal, Actual, Total
#
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/MatinMasimli/DataScience_ML_Udemy_Exercises/master/Ecommerce_purchases/Ecommerce%20Purchases.csv")
df.loc[0:4]
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# ¿Qué dimensiones tienen nuestros datos?

# %%
filas,columnas=df.shape
filas,columnas
# Out:
# (10000, 14)

# %%
df.info()                    #con .info puedo ver un poco más de información    
                             #nota: string=objeto para el sistema
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# (10000,14)
# ```

# %% [markdown]
# ¿Cuál es el precio medio de compra?

# %%
precio_medio=df["Purchase Price"].mean()
precio_medio
# Out:
# 50.347302

# %%
#El método manual nos devuelve más decimales, a veces es útil para hilar más fino. El manual no redondea sino que va hasta el final del cálculo

sum(df["Purchase Price"])/len(df["Purchase Price"])
# Out:
# 50.34730200000025

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# 50.34730200000025
# ```

# %% [markdown]
# Cuáles fueron, respectivamente, los precios mayores y menores de compra?

# %%
df["Purchase Price"].isnull().sum()           #quitar nulos
# Out:
# 0

# %%
df.duplicated().sum()                #Quitar duplicados
# Out:
# 0

# %%
df["Purchase Price"].max()                     #Calcular el máximo
# Out:
# 99.99

# %%
precio_mayor=df["Purchase Price"].max()
precio_mayor
# Out:
# 99.99

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# 99.989999999999995
# ```

# %%
precio_menor=df["Purchase Price"].min()
precio_menor
# Out:
# 0.0

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# 0.0
# ```

# %% [markdown]
# ¿Cuánta gente tiene indicado como inglés (valor 'en') el idioma preferente?

# %%
idioma_en=(df.loc[df["Language"]=="en"]).shape[0] 
idioma_en
# Out:
# 1098

# %%
df.loc[df["Language"]=="en"]                       #si los quisiera mostrar, haría lo mismo pero sin shape
# Out:
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# ...                                                 ...    ...      ...
# 9961        714 Joshua Ridges\nCarpenterville, NJ 37418  84 rK       PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# 1098
# ```

# %% [markdown]
# ¿Cuánta gente dispone del título profesional `'Lawyer'`?

# %%
Lawyers=(df.loc[df["Job"]=="Lawyer"]).shape[0] 
Lawyers
# Out:
# 30

# %%
df_lawyer = df.loc[df['Job'] == 'Lawyer']
df_lawyer.shape[0]
# Out:
# 30

# %%
df[df['Job'] == 'Lawyer'].count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %%
df[df['Job'] == 'Lawyer'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 470 to 9979
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           30 non-null     object
#  1   Lot               30 non-null     object
#  2   AM or PM          30 non-null     object
#  3   Browser Info      30 non-null     object
#  4   Company           30 non-null     object
#  5   Credit Card       30 non-null     int64
#  6   CC Exp Date       30 non-null     object
#  7   CC Security Code  30 non-null     int64
#  8   CC Provider       30 non-null     object
#  9   Email             30 non-null     object
#  10  Job               30 non-null     object
#  11  IP Address        30 non-null     object
#  12  Language          30 non-null     object
#  13  Purchase Price    30 non-null     float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 3.5+ KB

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# 30
# ```

# %% [markdown]
# ¿Cuántas personas hicieron compras durante la mañana, y cuántas durante la tarde?
#
# *(Pista: Use [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html))*

# %%
"""profe"""
df["AM or PM"].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
df["AM or PM"].value_counts().sort_index()
# Out:
# AM    4932
# PM    5068
# Name: AM or PM, dtype: int64

# %%
df["AM or PM"].value_counts(normalize=True)*100         #Para obtener en porcentaje
# Out:
# PM    50.68
# AM    49.32
# Name: AM or PM, dtype: float64

# %%
purchase_schedule_am=(df.loc[df["AM or PM"]=="AM"]).shape[0] 
purchase_schedule_pm=(df.loc[df["AM or PM"]=="PM"]).shape[0] 
print("PM ",purchase_schedule_pm)
print("AM ",purchase_schedule_am)
# Out:
# PM  5068
# AM  4932

# %%
df[df["AM or PM"] == 'AM'].count()
# Out:
# Address             4932
# Lot                 4932
# AM or PM            4932
# Browser Info        4932
# Company             4932
# Credit Card         4932
# CC Exp Date         4932
# CC Security Code    4932
# CC Provider         4932
# Email               4932
# Job                 4932
# IP Address          4932
# Language            4932
# Purchase Price      4932
# dtype: int64

# %%
df[df['AM or PM'] == 'PM'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5068 entries, 0 to 9998
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           5068 non-null   object
#  1   Lot               5068 non-null   object
#  2   AM or PM          5068 non-null   object
#  3   Browser Info      5068 non-null   object
#  4   Company           5068 non-null   object
#  5   Credit Card       5068 non-null   int64
#  6   CC Exp Date       5068 non-null   object
#  7   CC Security Code  5068 non-null   int64
#  8   CC Provider       5068 non-null   object
#  9   Email             5068 non-null   object
#  10  Job               5068 non-null   object
#  11  IP Address        5068 non-null   object
#  12  Language          5068 non-null   object
#  13  Purchase Price    5068 non-null   float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 593.9+ KB

# %%
df.loc[df["AM or PM"]=="AM"].value_counts()
# Out:
# Address                                                     Lot    AM or PM  Browser Info                                                                                                                                        Company                       Credit Card       CC Exp Date  CC Security Code  CC Provider                  Email                                  Job                                  IP Address       Language  Purchase Price
# 00009 Sharon Forks Apt. 078\nWest Sabrinabury, MA 45611     65 dS  AM        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_4) AppleWebKit/5320 (KHTML, like Gecko) Chrome/15.0.833.0 Safari/5320                                   Lopez, Barton and Miller      60423591589       04/17        362               VISA 16 digit                hhurst@gmail.com                       Development worker, community        254.48.96.123    fr        17.20             1
# ...

# %%
(df.loc[df["AM or PM"]=="AM"].value_counts()).shape[0]
# Out:
# 4932

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64
# ```

# %% [markdown]
# ¿Cuáles son las cinco profesiones más habituales?

# %%
df['Job'].value_counts()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: Job, Length: 623, dtype: int64

# %%
df['Job'].value_counts().head()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %%
df["Job"].value_counts().nlargest(5)    #otra forma de hacerlo, más "friki"
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64
# ```

# %% [markdown]
# Algún usuario hizo una compra que vino en el lote `90 WT`. ¿Cuál fue el precio de esa transacción?

# %%
df.loc[df["Lot"]=="90 WT"].head()
# Out:
#                                                Address    Lot AM or PM  \
# 513  50398 Mccoy Rest Suite 597\nSouth Garyborough,...  90 WT       AM
#
#                                           Browser Info     Company  \
# 513  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_2 like M...  Bright PLC
#
#       Credit Card CC Exp Date  CC Security Code       CC Provider  \
# 513  630438419693       11/19               173  American Express
#
#                 Email              Job     IP Address Language  Purchase Price
# 513  jesse00@page.net  Energy engineer  156.70.208.94       ru            75.1

# %%
precio_transaccion=df.loc[df["Lot"]=="90 WT","Purchase Price"]
precio_transaccion
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
df.loc[df["Lot"]=="90 WT","Purchase Price"].values[0]
# Out:
# 75.1

# %%
df.loc[df["Lot"]=="90 WT","Purchase Price"].iloc[0]
# Out:
# 75.1

# %%
df.loc[df["Lot"]=="90 WT","Purchase Price"].iat[0]
# Out:
# 75.1

# %%
df.loc[df["Lot"]=="90 WT","Purchase Price"].item()
# Out:
# 75.1

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# 513    75.1
# Name: Purchase Price, dtype: float64
# ```

# %% [markdown]
# ¿Cuál es el email de la persona con tarjeta de crédito `4926535242672853`?

# %%
# Out:
# Series([], Name: Email, dtype: object)

# %%
df.loc[df["Credit Card"]==4926535242672853].head()
# Out:
#                                                 Address    Lot AM or PM  \
# 1234  2470 Maria Manors Suite 185\nJoneshaven, MN 87251  82 UX       PM
#
#                                            Browser Info  \
# 1234  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.5.20) G...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 1234  Cole, King and Bowers  4926535242672853       09/21               188
#
#            CC Provider                         Email  \
# 1234  American Express  bondellen@williams-garza.com
#
#                                     Job    IP Address Language  Purchase Price
# 1234  Planning and development surveyor  159.182.3.50       ru           77.88

# %%
df.loc[df["Credit Card"]==630438419693].head()
# Out:
#                                                Address    Lot AM or PM  \
# 513  50398 Mccoy Rest Suite 597\nSouth Garyborough,...  90 WT       AM
#
#                                           Browser Info     Company  \
# 513  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_2 like M...  Bright PLC
#
#       Credit Card CC Exp Date  CC Security Code       CC Provider  \
# 513  630438419693       11/19               173  American Express
#
#                 Email              Job     IP Address Language  Purchase Price
# 513  jesse00@page.net  Energy engineer  156.70.208.94       ru            75.1

# %%
df.loc[df["Credit Card"]==630438419693,["Email","Credit Card"]]
# Out:
#                 Email   Credit Card
# 513  jesse00@page.net  630438419693

# %%
df.loc[df["Credit Card"]==6011485664704662,["Email","Credit Card"]]
# Out:
#                         Email       Credit Card
# 9970  rangelbrian@hotmail.com  6011485664704662

# %%
df.loc[df["Credit Card"]==6011485664704662,"Email"]
# Out:
# 9970    rangelbrian@hotmail.com
# Name: Email, dtype: object

# %%
df.loc[df["Credit Card"]==4926535242672853].head()
# Out:
#                                                 Address    Lot AM or PM  \
# 1234  2470 Maria Manors Suite 185\nJoneshaven, MN 87251  82 UX       PM
#
#                                            Browser Info  \
# 1234  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.5.20) G...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 1234  Cole, King and Bowers  4926535242672853       09/21               188
#
#            CC Provider                         Email  \
# 1234  American Express  bondellen@williams-garza.com
#
#                                     Job    IP Address Language  Purchase Price
# 1234  Planning and development surveyor  159.182.3.50       ru           77.88

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object
# ```

# %% [markdown]
# ¿Cuánta gente tiene `American Express` como proveedor de crédito e hizo una compra superior a `$95`?

# %%
df.loc[(df["CC Provider"]=="American Express") & (df["Purchase Price"]> 95)]
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 280   81060 Dustin Causeway Apt. 503\nPort Danielche...  80 zh       PM
# 372              359 Stanley Coves\nSalasfort, SD 59457  75 Ub       PM
# 677       4855 Peter Bridge\nJohnsonberg, PA 90599-0009  62 Nx       AM
# 766             386 Alisha Unions\nSteelebury, ND 19782  28 pJ       PM
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572  09 vg       PM
# 1381  79284 Lisa Mews Suite 069\nKellyborough, CT 71...  45 MR       PM
# 1385  67796 James Keys Suite 656\nSouth Katieshire, ...  06 ia       PM
# 1568       76108 Barker Manors\nEast Amy, PW 49544-5921  82 Qw       AM
# 1727  478 Anita Hill Apt. 766\nAverymouth, FM 50629-...  94 qM       AM
# 2146           557 Barton Harbor\nFuentesport, VI 29961  96 MV       AM
# 2264   040 Ingram Way Suite 602\nEast Matthew, AR 67341  52 WA       AM
# ...

# %%
df.loc[(df["CC Provider"]=="American Express") & (df["Purchase Price"]> 95)].shape[0]
# Out:
# 39

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# 39
# ```

# %% [markdown]
# ¿Cuánta gente tiene una tarjeta de crédito que expira en 2025?

# %%
df[df["CC Exp Date"].str.endswith("/25")].shape[0]
# Out:
# 1033

# %%
df["Year"]=df["CC Exp Date"].str.split("/").str[1]
df[df["Year"]=="25"].shape[0]
# Out:
# 1033

# %%
get_year=lambda x:int(x.split("/")[1])
df["Year"]=df["CC Exp Date"].apply(get_year)
df[df["Year"]==25].shape[0]
# Out:
# 1033

# %%
import datetime as dt
df["CC Exp Date"]=pd.to_datetime(df["CC Exp Date"],format="%m/%y")

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# 1033
# ```

# %% [markdown]
# ¿Cuáles fueron los cinco *email hosts* más populares (e.g., gmail, yahoo,...)?

# %%
df["Domain"]=df["Email"].str.split("@").str[1]
df['Domain'].value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Domain, dtype: int64

# %% [markdown]
# *Respuesta esperada:*
#
# ```python
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64
# ```
